# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
data = xr.load_dataset('/p/scratch/cjibg36/kaandorp2/data/ERA5_EUR-11_CLM_test/2010-01.nc')
data
# Out:
# <xarray.Dataset>
# Dimensions:   (lsmlat: 432, lsmlon: 444, ncl7: 1, ncl8: 1, ncl9: 1, ncl10: 1, time: 744, lat: 432, lon: 444)
# Coordinates:
#   * time      (time) datetime64[ns] 2010-01-01 ... 2010-01-31T23:00:00
# Dimensions without coordinates: lsmlat, lsmlon, ncl7, ncl8, ncl9, ncl10, lat, lon
# Data variables: (12/18)
#     NUMLON    (lsmlat) float64 444.0 444.0 444.0 444.0 ... 444.0 444.0 444.0
#     LONGXY    (lsmlat, lsmlon) float64 -10.58 -10.48 -10.38 ... 68.53 68.73
#     LATIXY    (lsmlat, lsmlon) float64 20.58 20.62 20.66 ... 67.03 66.97 66.9
#     LONE      (lsmlat, lsmlon) float64 -10.53 -10.43 -10.33 ... 68.63 68.83
#     LATN      (lsmlat, lsmlon) float64 20.63 20.67 20.71 ... 67.08 67.01 66.94
#     LONW      (lsmlat, lsmlon) float64 -10.63 -10.53 -10.43 ... 68.43 68.63
#     ...        ...
#     TBOT      (time, lat, lon) float32 289.4 289.4 289.4 ... 243.9 244.1 244.7
#     FLDS      (time, lat, lon) float32 297.0 297.1 297.3 ... 197.4 197.3 197.9
# ...

# %%
data.Tdew.min()
# Out:
# <xarray.DataArray 'Tdew' ()>
# array(224.17227173)

# %%
# %matplotlib inline
plt.figure()
data.Tdew[0].plot.pcolormesh()
